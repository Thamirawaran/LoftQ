# %% [markdown]
# # Load the model

# %% [markdown]
# # Quantize and save the model

# %% [markdown]
# # Load the dataset

# %% [markdown]
# # Load the quantized model, train and save

# %% [markdown]
# # Evaluate the LoftQ quantized model

# %% [markdown]
# # Quantize with bnb, train and save

# %% [markdown]
# # Evaluate normal quantized model

# %% [markdown]
# # Evaluate the base model (without quantization)
